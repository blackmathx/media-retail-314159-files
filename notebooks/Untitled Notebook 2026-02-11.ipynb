# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %%
# %sql

SELECT * FROM parquet.`s3://media-retail-314159/raw/employee/*/*.parquet`;

# %%
spark = SparkSession.builder.appName("QueryEmployee").getOrCreate()

df = spark.read.parquet("s3://media-retail-314159/raw/employee/2026-02-14/")
df.filter(col("employee_id") == 1).show()

dfa = spark.read.parquet("s3://media-retail-314159/staged/employee/")
dfa.filter(col("employee_id") == 1).show()

# %%
display(dbutils.fs.ls("s3://media-retail-314159/raw/employee/"))

# %%
display(dbutils.fs.ls("s3://media-retail-314159/raw/employee/2026-02-14/"))

# %%
spark.read.format("delta").option("recursiveFileLookup","true").load("s3://media-retail-314159/staged/media_type/")
